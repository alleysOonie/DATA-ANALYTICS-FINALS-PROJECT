# %% [markdown]
# <h1> <strong> FINAL PROJECT - Family Income and Expenditure </h1> <hr>
#
# <ul> ANALYSTS :
# <li> Calderon, Nichole Allyson D. </li>
# <LI> Esguerra, Nathaniel L. </LI></ul>

# %% [markdown]
# <h2> <b> Libraries </h2>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %% [markdown]
# <h2> <b> Dataset </h2>

# %%
FIE =  pd.read_csv('datasets\\Family Income and Expenditure.csv')

# %%
FIE
# Out:
#        Total Household Income              Region  Total Food Expenditure  \
# 0                      480332                 CAR                  117848
# 1                      198235                 CAR                   67766
# 2                       82785                 CAR                   61609
# 3                      107589                 CAR                   78189
# 4                      189322                 CAR                   94625
# ...                       ...                 ...                     ...
# 41539                  119773  XII - SOCCSKSARGEN                   44875
# 41540                  137320  XII - SOCCSKSARGEN                   31157
# 41541                  133171  XII - SOCCSKSARGEN                   45882
# 41542                  129500  XII - SOCCSKSARGEN                   81416
# 41543                  128598  XII - SOCCSKSARGEN                   78195
#
#             Main Source of Income  Agricultural Household indicator  \
# ...

# %% [markdown]
# <H2><B> Descriptive </H2>

# %% [markdown]
# <H3> <B> 1. Which region has the highest total food expenditure? </H3>

# %%
region_food_expenditure = FIE.groupby("Region")["Total Food Expenditure"].sum()

# %%
region_food_expenditure
# Out:
# Region
#  ARMM                        145965496
# CAR                          138608546
# Caraga                       128148360
# I - Ilocos Region            189366054
# II - Cagayan Valley          167766071
# III - Central Luzon          322815333
# IVA - CALABARZON             438399898
# IVB - MIMAROPA                88379607
# IX - Zasmboanga Peninsula    124525829
# NCR                          524842286
# V - Bicol Region             189877811
# VI - Western Visayas         227592553
# VII - Central Visayas        214224555
# VIII - Eastern Visayas       163201892
# X - Northern Mindanao        120980449
# XI - Davao Region            198436464
# XII - SOCCSKSARGEN           152228224
# Name: Total Food Expenditure, dtype: int64

# %%
region_food_expenditure.idxmax()
# Out:
# 'NCR'

# %%
region_food_expenditure.max()
# Out:
# np.int64(524842286)

# %% [markdown]
# <h2> <b> Visualization </h2>

# %%
plt.figure(figsize=(8,6))
plt.barh(region_food_expenditure.index, region_food_expenditure.values, color="lightpink")
plt.xlabel("Total Food Expenditure")
plt.ylabel("Region")
plt.title("Total Food Expenditure per Region")
plt.tight_layout()
plt.show()

# %% [markdown]
# <h3> INSIGHT #1 : The region with the highest total food expenditure is NCR, with a total of 524,842,286. </h3>

# %% [markdown]
# <h3> <b> 2. What is the main source of income in Region IV-A (CALABARZON)? </h3>

# %%
calabarzon = FIE[FIE["Region"] == "IVA - CALABARZON"]

# %%
calabarzon
# Out:
#        Total Household Income            Region  Total Food Expenditure  \
# 2520                   118410  IVA - CALABARZON                   71019
# 2521                   151380  IVA - CALABARZON                   80889
# 2522                   282373  IVA - CALABARZON                  112023
# 2523                   146190  IVA - CALABARZON                   77491
# 2524                    95530  IVA - CALABARZON                   67688
# ...                       ...               ...                     ...
# 30625                  224016  IVA - CALABARZON                  114730
# 30626                  351448  IVA - CALABARZON                  129143
# 30627                  191092  IVA - CALABARZON                   82154
# 30628                  549970  IVA - CALABARZON                  140874
# 30629                   73780  IVA - CALABARZON                   46645
#
#          Main Source of Income  Agricultural Household indicator  \
# ...

# %%
main_income = calabarzon["Main Source of Income"].mode()[0]

# %%
main_income
# Out:
# 'Wage/Salaries'

# %% [markdown]
# <h3> <b> Visualization </h3>

# %%
income = calabarzon["Main Source of Income"].value_counts()

# %%
income
# Out:
# Main Source of Income
# Wage/Salaries                 2466
# Other sources of Income       1021
# Enterpreneurial Activities     675
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 5))
plt.bar(income.index, income.values, color = "maroon")
plt.xlabel("Main Source of Income")
plt.title("Main Sources of Income in Region IV-A (CALABARZON)")
plt.tight_layout()
plt.show()

# %% [markdown]
# <h3> INSIGHT #2 : The primary source of income in Region IV-A (CALABARZON) is wage/salaries with 2,466. </h3>

# %% [markdown]
# <H2> <B> 2.0 (General) </H2>

# %%
main_income_general = FIE["Main Source of Income"].mode()[0]

# %%
main_income_general
# Out:
# 'Wage/Salaries'

# %% [markdown]
# <h2> <b> Visualization (General) </h2>

# %%
income_general = FIE["Main Source of Income"].value_counts()

# %%
income_general
# Out:
# Main Source of Income
# Wage/Salaries                 20388
# Other sources of Income       10836
# Enterpreneurial Activities    10320
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 5))
plt.bar(income_general.index, income_general.values, color = "indianred")
plt.xlabel("Main Source of Income")
plt.title("Main Sources of Income across all Regions")
plt.tight_layout()
plt.show()

# %% [markdown]
# <h3> INSIGHT #2 (General) : Wage/salaries are the main source of income in all regions, with a total of 20,388. </h3>

# %% [markdown]
# <H2> <B> 3. Which household head occupation in Region IV-A (CALABARZON) has the highest total rice expenditure? </H2>

# %%
calabarzon = FIE[FIE["Region"] == "IVA - CALABARZON"]

# %%
calabarzon
# Out:
#        Total Household Income            Region  Total Food Expenditure  \
# 2520                   118410  IVA - CALABARZON                   71019
# 2521                   151380  IVA - CALABARZON                   80889
# 2522                   282373  IVA - CALABARZON                  112023
# 2523                   146190  IVA - CALABARZON                   77491
# 2524                    95530  IVA - CALABARZON                   67688
# ...                       ...               ...                     ...
# 30625                  224016  IVA - CALABARZON                  114730
# 30626                  351448  IVA - CALABARZON                  129143
# 30627                  191092  IVA - CALABARZON                   82154
# 30628                  549970  IVA - CALABARZON                  140874
# 30629                   73780  IVA - CALABARZON                   46645
#
#          Main Source of Income  Agricultural Household indicator  \
# ...

# %%
occupation_rice = calabarzon.groupby('Household Head Occupation')['Total Rice Expenditure'].sum().reset_index()

# %%
occupation_rice
# Out:
#                              Household Head Occupation  Total Rice Expenditure
# 0                             Accountants and auditors                  114245
# 1                    Accounting and bookkeeping clerks                   24750
# 2    Administrative secretaries and related associa...                   40231
# 3                   Agronomists and related scientists                   12740
# 4                    Air transport service supervisors                   34428
# ..                                                 ...                     ...
# 233               Wood and related products assemblers                   26119
# 234                    Wood processing plant operators                   25488
# 235                    Wood products machine operators                   28538
# 236   Woodworking machine setters and setter-operators                   12922
# 237  Workers reporting occupations unidentifiable o...                   59015
#
# [238 rows x 2 columns]

# %%
highest_rice_occupation = occupation_rice.sort_values('Total Rice Expenditure', ascending=False).head(1)

# %%
highest_rice_occupation
# Out:
#                             Household Head Occupation  Total Rice Expenditure
# 81  General managers/managing proprietors in trans...                 4468701

# %% [markdown]
# <h2> <b> Visualization </h2>

# %%
top_expender = occupation_rice.sort_values('Total Rice Expenditure', ascending=False).head(30)

# %%
top_expender
# Out:
#                              Household Head Occupation  Total Rice Expenditure
# 81   General managers/managing proprietors in trans...                 4468701
# 82   General managers/managing proprietors in whole...                 3395629
# 64                              Farmhands and laborers                 3207548
# 18                      Building construction laborers                 2546163
# 23                           Car, taxi and van drivers                 2543823
# 177               Protective services workers n. e. c.                 1728308
# 24                              Carpenters and joiners                 1609695
# 118              Masons and related concrete finishers                 1526604
# 84   General managers/managing proprietors of busin...                 1462474
# 180                                       Rice farmers                 1408430
# 79   General managers/managing proprietors in manuf...                 1271657
# ...

# %%
plt.figure(figsize=(15,11))
plt.barh(top_expender['Household Head Occupation'], top_expender['Total Rice Expenditure'], color='darkkhaki')
plt.xlabel('Total Rice Expenditure')
plt.ylabel('Household Head Occupation')
plt.title('Top 30 Household Head Occupations by Rice Expenditure in Region IVA (CALABARZON)')
plt.gca().invert_yaxis() 
plt.tight_layout()
plt.show()

# %% [markdown]
# <h3> INSIGHT #3 : General managers/managing proprietors in transportation, storage, and communications are the household head occupation in Region IV-A (CALABARZON) with the highest rice expenditure, totaling over 4,468,701. </h3>

# %% [markdown]
# <h2> <b> 3.0 (General) </h2>

# %%
occupation_rice_general = FIE.groupby('Household Head Occupation')['Total Rice Expenditure'].sum().reset_index()

# %%
occupation_rice_general
# Out:
#                              Household Head Occupation  Total Rice Expenditure
# 0                             Accountants and auditors                  683877
# 1                    Accounting and bookkeeping clerks                 1078517
# 2    Administrative secretaries and related associa...                  480762
# 3            Advertising and public relations managers                   20840
# 4    Agricultural or industrial machinery mechanics...                  209763
# ..                                                 ...                     ...
# 373                    Wood products machine operators                  344784
# 374                                      Wood treaters                   14480
# 375   Woodworking machine setters and setter-operators                   58680
# 376               Word processor and related operators                   72449
# 377  Workers reporting occupations unidentifiable o...                  480171
#
# [378 rows x 2 columns]

# %%
highest_rice_occupation_general = occupation_rice_general.sort_values('Total Rice Expenditure', ascending=False).head(1)

# %%
highest_rice_occupation_general
# Out:
#     Household Head Occupation  Total Rice Expenditure
# 287              Rice farmers                64078289

# %% [markdown]
# <h2> <b> Visualization (General) </h2>

# %%
top_expender_general = occupation_rice_general.sort_values('Total Rice Expenditure', ascending=False).head(30)

# %%
top_expender_general
# Out:
#                              Household Head Occupation  Total Rice Expenditure
# 287                                       Rice farmers                64078289
# 103                             Farmhands and laborers                63702220
# 128  General managers/managing proprietors in trans...                37222275
# 129  General managers/managing proprietors in whole...                35003936
# 68                                        Corn farmers                24349004
# 158                Inland and coastal waters fishermen                21290170
# 38                              Carpenters and joiners                20258554
# 30                      Building construction laborers                18774667
# 52                                     Coconut farmers                17382020
# 37                           Car, taxi and van drivers                15983385
# 281               Protective services workers n. e. c.                12434476
# ...

# %%
plt.figure(figsize=(15,11))
plt.barh(top_expender_general['Household Head Occupation'], top_expender_general['Total Rice Expenditure'], color='tan')
plt.xlabel('Total Rice Expenditure')
plt.ylabel('Household Head Occupation')
plt.title('Top 30 Household Head Occupations by Rice Expenditure in all Regions')
plt.gca().invert_yaxis() 
plt.tight_layout()
plt.show()

# %% [markdown]
# <h3> INSIGHT #3 (General) : In all regions, rice farmers are the household head occupation with the highest rice expenditure, totaling over 64,078,289.</h3>

# %% [markdown]
# <h2> <b> 4. Which household head sex has the highest expenditure on medical care in Region IV-A (CALABARZON)? </h2>

# %%
calabarzon = FIE[FIE["Region"] == "IVA - CALABARZON"]

# %%
calabarzon
# Out:
#        Total Household Income            Region  Total Food Expenditure  \
# 2520                   118410  IVA - CALABARZON                   71019
# 2521                   151380  IVA - CALABARZON                   80889
# 2522                   282373  IVA - CALABARZON                  112023
# 2523                   146190  IVA - CALABARZON                   77491
# 2524                    95530  IVA - CALABARZON                   67688
# ...                       ...               ...                     ...
# 30625                  224016  IVA - CALABARZON                  114730
# 30626                  351448  IVA - CALABARZON                  129143
# 30627                  191092  IVA - CALABARZON                   82154
# 30628                  549970  IVA - CALABARZON                  140874
# 30629                   73780  IVA - CALABARZON                   46645
#
#          Main Source of Income  Agricultural Household indicator  \
# ...

# %%
sex_medical_care = calabarzon.groupby('Household Head Sex')['Medical Care Expenditure'].sum()

# %%
sex_medical_care
# Out:
# Household Head Sex
# Female    12575463
# Male      32103690
# Name: Medical Care Expenditure, dtype: int64

# %% [markdown]
# <h2> <b> Visualization </h2>

# %%
plt.figure(figsize=(6,6))
plt.pie(sex_medical_care, labels=sex_medical_care.index, autopct='%1.1f%%', startangle=90, colors=['olive', 'darkolivegreen'])
plt.title('Medical Care Expenditure by Household Head Sex in Region IV-A (CALABARZON)')
plt.show()

# %% [markdown]
# <H3> INSIGHT #4 : Males in Region IV-A (CALABARZON) have the highest expenditure on medical care, over 71.9% (32,103,690). </H3>

# %% [markdown]
# <h2> <b> 4.0 (General) </h2>

# %%
sex_medical_care_general = FIE.groupby('Household Head Sex')['Medical Care Expenditure'].sum()

# %%
sex_medical_care_general
# Out:
# Household Head Sex
# Female     82879532
# Male      214585102
# Name: Medical Care Expenditure, dtype: int64

# %% [markdown]
# <h2> <b> Visualization (General) </h2>

# %%
plt.figure(figsize=(6,6))
plt.pie(sex_medical_care_general, labels=sex_medical_care_general.index, autopct='%1.1f%%', startangle=90, colors=['limegreen', 'forestgreen'])
plt.title('Medical Care Expenditure by Household Head Sex in all Regions')
plt.show()

# %% [markdown]
# <h3> INSIGHT #4 (General) : Across all regions, males spend the most on medical care, over 72.1% (214,585,102). </h3>

# %% [markdown]
# <H2> <B> 5. How many households in Region IV-A (CALABARZON) are agricultural households? </H2>

# %%
calabarzon = FIE[FIE["Region"] == "IVA - CALABARZON"]

# %%
calabarzon
# Out:
#        Total Household Income            Region  Total Food Expenditure  \
# 2520                   118410  IVA - CALABARZON                   71019
# 2521                   151380  IVA - CALABARZON                   80889
# 2522                   282373  IVA - CALABARZON                  112023
# 2523                   146190  IVA - CALABARZON                   77491
# 2524                    95530  IVA - CALABARZON                   67688
# ...                       ...               ...                     ...
# 30625                  224016  IVA - CALABARZON                  114730
# 30626                  351448  IVA - CALABARZON                  129143
# 30627                  191092  IVA - CALABARZON                   82154
# 30628                  549970  IVA - CALABARZON                  140874
# 30629                   73780  IVA - CALABARZON                   46645
#
#          Main Source of Income  Agricultural Household indicator  \
# ...

# %%
calabarzon_agricultural_household = calabarzon['Agricultural Household indicator'].value_counts()

# %%
calabarzon_agricultural_household
# Out:
# Agricultural Household indicator
# 0    3872
# 1     290
# Name: count, dtype: int64

# %%
calabarzon_agricultural_household.index = ['Non-Agricultural', 'Agricultural']

# %% [markdown]
# <H2> <B> Visualization </H2>

# %%
plt.figure(figsize=(6,6))
plt.pie(calabarzon_agricultural_household, labels=calabarzon_agricultural_household.index, autopct='%1.1f%%', startangle=90, colors=['mediumpurple', 'thistle'])
plt.title('Agricultural vs Non-Agricultural Households in Region IV-A (CALABARZON)')
plt.axis('equal')
plt.show()

# %% [markdown]
# <h3> INSIGHT #5 : There are 290 agricultural households in Region IV-A (CALABARZON). </h3>

# %% [markdown]
# <H2> <b> 5.0 (General) </H2>

# %%
agricultural_household = FIE['Agricultural Household indicator'].value_counts()

# %%
agricultural_household
# Out:
# Agricultural Household indicator
# 0    28106
# 1     9018
# 2     4420
# Name: count, dtype: int64

# %% [markdown]
# <h3> INSIGHT #5 (General) : There are 13,438 agricultural households across all the regions. </h3>

# %% [markdown]
# <h2> <b> Diagnostic </h2>

# %% [markdown]
# <h2> <b> 1. Is there a difference in the average total food expenditure between households with a job/business and those without a job/business in Region IV-A (CALABARZON)? </h2>

# %%
calabarzon = FIE[FIE["Region"] == "IVA - CALABARZON"]

# %%
calabarzon
# Out:
#        Total Household Income            Region  Total Food Expenditure  \
# 2520                   118410  IVA - CALABARZON                   71019
# 2521                   151380  IVA - CALABARZON                   80889
# 2522                   282373  IVA - CALABARZON                  112023
# 2523                   146190  IVA - CALABARZON                   77491
# 2524                    95530  IVA - CALABARZON                   67688
# ...                       ...               ...                     ...
# 30625                  224016  IVA - CALABARZON                  114730
# 30626                  351448  IVA - CALABARZON                  129143
# 30627                  191092  IVA - CALABARZON                   82154
# 30628                  549970  IVA - CALABARZON                  140874
# 30629                   73780  IVA - CALABARZON                   46645
#
#          Main Source of Income  Agricultural Household indicator  \
# ...

# %%
expenditure_business_job = calabarzon.groupby("Household Head Job or Business Indicator")["Total Food Expenditure"].mean()

# %%
expenditure_business_job
# Out:
# Household Head Job or Business Indicator
# No Job/Business      107473.173160
# With Job/Business    104723.497838
# Name: Total Food Expenditure, dtype: float64

# %% [markdown]
# <h2> <b> Visualization </h2>

# %%
plt.figure(figsize=(8,5))
plt.bar(expenditure_business_job.index, expenditure_business_job.values, color = "mediumaquamarine")
plt.xlabel("Household Head Job or Business Indicator")
plt.ylabel("Average Total Food Expenditure")
plt.title("Average Food Expenditure by Job/Business Status\n(Region IV-A: CALABARZON)")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h3> INSIGHT #1 : In Region IV-A, households with no job or business surprisingly have a slightly higher average food expenditure at ₱107,473.17 compared to households with a job or business, which only spend ₱104,723.50. </h3>

# %% [markdown]
# <H2> <B> 1.0 (General) </H2>

# %%
expenditure_business_job_general = FIE.groupby("Household Head Job or Business Indicator")["Total Food Expenditure"].mean()

# %%
expenditure_business_job_general
# Out:
# Household Head Job or Business Indicator
# No Job/Business      88497.879246
# With Job/Business    84346.018878
# Name: Total Food Expenditure, dtype: float64

# %% [markdown]
# <h2> <b> Visualization (General) </h2>

# %%
plt.figure(figsize=(8,5))
plt.bar(expenditure_business_job_general.index, expenditure_business_job_general.values, color = "teal")
plt.xlabel("Household Head Job or Business Indicator")
plt.ylabel("Average Total Food Expenditure")
plt.title("Average Food Expenditure by Job/Business Status\n across all the Regions")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h3> INSIGHT #1 (General) : When looking at all regions, households without a job or business spend more on food on average (₱88,497.88) than those with a job or business, who spend ₱84,346.02.</h3>

# %% [markdown]
# <h2> <b> 2. Are households relying on wage/salaries earning more or less than those depending on entrepreneurial activities or other sources in CALABARZON? </h2>

# %%
calabarzon = FIE[FIE["Region"] == "IVA - CALABARZON"]

# %%
calabarzon
# Out:
#        Total Household Income            Region  Total Food Expenditure  \
# 2520                   118410  IVA - CALABARZON                   71019
# 2521                   151380  IVA - CALABARZON                   80889
# 2522                   282373  IVA - CALABARZON                  112023
# 2523                   146190  IVA - CALABARZON                   77491
# 2524                    95530  IVA - CALABARZON                   67688
# ...                       ...               ...                     ...
# 30625                  224016  IVA - CALABARZON                  114730
# 30626                  351448  IVA - CALABARZON                  129143
# 30627                  191092  IVA - CALABARZON                   82154
# 30628                  549970  IVA - CALABARZON                  140874
# 30629                   73780  IVA - CALABARZON                   46645
#
#          Main Source of Income  Agricultural Household indicator  \
# ...

# %%
income_by_source = calabarzon.groupby("Main Source of Income")["Total Household Income"].mean().reset_index()

# %%
income_by_source
# Out:
#         Main Source of Income  Total Household Income
# 0  Enterpreneurial Activities           284760.488889
# 1     Other sources of Income           314513.140059
# 2               Wage/Salaries           303834.268045

# %%
income_by_source.sort_values('Total Household Income', ascending=False).head(1)
# Out:
#      Main Source of Income  Total Household Income
# 1  Other sources of Income           314513.140059

# %% [markdown]
# <h2> <b> Visualization </h2>

# %%
plt.figure(figsize=(8,5))
plt.bar(income_by_source["Main Source of Income"], income_by_source["Total Household Income"], color=["lightblue", "cadetblue", "steelblue"])
plt.xlabel("Main Source of Income")
plt.ylabel("Average Total Household Income")
plt.title("Average Household Income by Main Source of Income in Region IV-A (CALABARZON)")
plt.tight_layout()
plt.show()

# %% [markdown]
# <H3> INSIGHT #2 & #2.1 : Households relying on entrepreneurial activities tend to earn less than those depending on wages/salaries or other income sources in Region IV-A. Other sources of income produce the highest average household income overall.</H3>

# %% [markdown]
# <H2> <B> 2.0 (General) </H2>

# %%
income_by_source_general = FIE.groupby("Main Source of Income")["Total Household Income"].mean().reset_index()

# %%
income_by_source_general
# Out:
#         Main Source of Income  Total Household Income
# 0  Enterpreneurial Activities           213484.383721
# 1     Other sources of Income           242638.827243
# 2               Wage/Salaries           267414.952080

# %%
income_by_source_general.sort_values('Total Household Income', ascending=False).head(1)
# Out:
#   Main Source of Income  Total Household Income
# 2         Wage/Salaries            267414.95208

# %% [markdown]
# <h2> <b> Visualization (General) </h2>

# %%
plt.figure(figsize=(8,5))
plt.bar(income_by_source_general["Main Source of Income"], income_by_source_general["Total Household Income"], color=["gray", "dimgray", "black"])
plt.xlabel("Main Source of Income")
plt.ylabel("Average Total Household Income")
plt.title("Average Household Income by Main Source of Income in all Regions")
plt.tight_layout()
plt.show()

# %% [markdown]
# <h3> INSIGHT #2 & #2.1 (General): Across all regions, households whose main income comes from wages or salaries have the highest average total household income at ₱267,414.95. Those relying on other sources of income follow with an average of ₱242,638.83. Meanwhile, households depending on entrepreneurial activities have the lowest average household income at ₱213,484.38. </h3>

# %% [markdown]
# <h2> <b> 3. Do households with no job or business spend more on education or on tobacco in Region IV-A? </h2>

# %%
calabarzon = FIE[FIE["Region"] == "IVA - CALABARZON"]

# %%
calabarzon
# Out:
#        Total Household Income            Region  Total Food Expenditure  \
# 2520                   118410  IVA - CALABARZON                   71019
# 2521                   151380  IVA - CALABARZON                   80889
# 2522                   282373  IVA - CALABARZON                  112023
# 2523                   146190  IVA - CALABARZON                   77491
# 2524                    95530  IVA - CALABARZON                   67688
# ...                       ...               ...                     ...
# 30625                  224016  IVA - CALABARZON                  114730
# 30626                  351448  IVA - CALABARZON                  129143
# 30627                  191092  IVA - CALABARZON                   82154
# 30628                  549970  IVA - CALABARZON                  140874
# 30629                   73780  IVA - CALABARZON                   46645
#
#          Main Source of Income  Agricultural Household indicator  \
# ...

# %%
calabarzon_no_job = calabarzon[calabarzon["Household Head Job or Business Indicator"] == "No Job/Business"]

# %%
calabarzon_no_job
# Out:
#        Total Household Income            Region  Total Food Expenditure  \
# 2522                   282373  IVA - CALABARZON                  112023
# 2528                   132998  IVA - CALABARZON                   63294
# 2530                   174080  IVA - CALABARZON                   82946
# 2533                   216180  IVA - CALABARZON                   79171
# 2535                   349453  IVA - CALABARZON                  109367
# ...                       ...               ...                     ...
# 30596                  156769  IVA - CALABARZON                   61720
# 30598                  311809  IVA - CALABARZON                  149591
# 30613                  184532  IVA - CALABARZON                   53482
# 30618                  282500  IVA - CALABARZON                  120359
# 30628                  549970  IVA - CALABARZON                  140874
#
#          Main Source of Income  Agricultural Household indicator  \
# ...

# %%
alcohol_tobacco_no_job = calabarzon_no_job[["Alcoholic Beverages Expenditure", "Tobacco Expenditure"]].mean()

# %%
alcohol_tobacco_no_job
# Out:
# Alcoholic Beverages Expenditure     641.067100
# Tobacco Expenditure                2300.230519
# dtype: float64

# %% [markdown]
# <h2> <b> Visualization </h2>

# %%
plt.figure(figsize=(7,5))
plt.bar(alcohol_tobacco_no_job.index, alcohol_tobacco_no_job.values, color = ["mediumblue", "midnightblue"])
plt.xlabel("Expenditure Type")
plt.ylabel("Average Expenditure")
plt.title("Average Alcoholic Beverages vs Tobacco Expenditure\n(No Job/Business Households, Region IV-A)")
plt.tight_layout()
plt.show()

# %% [markdown]
# <h3> INSIGHT #3 : Households with no job or business in Region IV-A (CALABARZON) spend much more on tobacco (₱2,300.23) than on alcoholic beverages (₱641.07).</h3>

# %% [markdown]
# <H2> <B> 3.0 (General)</H2>

# %%
no_job = FIE[FIE["Household Head Job or Business Indicator"] == "No Job/Business"]

# %%
no_job
# Out:
#        Total Household Income              Region  Total Food Expenditure  \
# 8                      171152                 CAR                   67348
# 13                     128214                 CAR                   62262
# 14                      91525                 CAR                   45487
# 15                     171742                 CAR                   70892
# 26                      84330                 CAR                   45509
# ...                       ...                 ...                     ...
# 41520                  695292  XII - SOCCSKSARGEN                  136459
# 41529                   95500  XII - SOCCSKSARGEN                   73138
# 41533                  153500  XII - SOCCSKSARGEN                   70991
# 41535                  166600  XII - SOCCSKSARGEN                   90786
# 41543                  128598  XII - SOCCSKSARGEN                   78195
#
#             Main Source of Income  Agricultural Household indicator  \
# ...

# %%
no_job_alcohol_tobacco = no_job[["Alcoholic Beverages Expenditure", "Tobacco Expenditure"]].mean()

# %%
no_job_alcohol_tobacco
# Out:
# Alcoholic Beverages Expenditure     813.770833
# Tobacco Expenditure                1878.985138
# dtype: float64

# %% [markdown]
# <h2> <b> Visualization (General) </h2>

# %%
plt.figure(figsize=(7,5))
plt.bar(no_job_alcohol_tobacco.index, no_job_alcohol_tobacco.values, color = ["lightsalmon", "sienna"])
plt.xlabel("Expenditure Type")
plt.ylabel("Average Expenditure")
plt.title("Average Alcoholic Beverages vs Tobacco Expenditure\n(No Job/Business Households across all Regions)")
plt.tight_layout()
plt.show()
